# %% [markdown]
# # Project 07 real-data dependency discovery
# Private Kaggle-only run. This stage queries metadata and hashes the pinned HoVer-Net checkpoint. It downloads no slide bytes and produces no benchmark metric.

# %%
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', '/kaggle/working/07-f2-histognn/requirements-kaggle-real-data.txt'], check=True)

# %%
import os, subprocess, sys
os.chdir('/kaggle/working/07-f2-histognn')
result = subprocess.run([sys.executable, 'scripts/kaggle_real_data_discovery.py'], check=False)
if result.returncode != 3:
    raise RuntimeError(f'unexpected discovery exit code: {result.returncode}')
print('Discovery stopped at the expected hash-pinning gate.')
