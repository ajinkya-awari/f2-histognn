# %% [markdown]
# # Project 07 bounded real-data graph smoke
# Private Kaggle-only execution. Six case-disjoint TCGA slides are checksum-verified, sampled into bounded tiles, processed with pinned HoVer-Net PanNuke weights, and passed through the four graph-model forward contracts. This notebook emits no benchmark metric.

# %%
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', '/kaggle/working/07-f2-histognn/requirements-kaggle-torch-p100.txt'], check=True)
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', '/kaggle/working/07-f2-histognn/requirements-kaggle-real-data.txt'], check=True)

# %%
import os, subprocess, sys
os.chdir('/kaggle/working/07-f2-histognn')
subprocess.run([sys.executable, 'scripts/kaggle_real_data_pilot.py'], check=True)
